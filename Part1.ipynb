# %% [markdown]
# <a href="https://colab.research.google.com/github/WanjohiWanjohi/NNGooglePathway/blob/main/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#create simple neural network with one layer
model = tf.keras.Sequential([keras.layers.Dense(units=1 , input_shape=[1])])

# %%
#compile neural network by specifying a loss function and an optimizer function
model.compile(optimizer='sgd' , loss='mean_squared_error')

# %%
#provide the data
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
#train neural network
model.fit(x=xs,y=ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 460ms/step - loss: 88.3875
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 69.5441
# Epoch 3/500
# 1/1 [==============================] - 0s 3ms/step - loss: 54.7189
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 43.0550
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 33.8783
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 26.6584
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 20.9781
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 16.5090
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 12.9928
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 10.2264
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0498
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3373
# ...

# %%
#using the model
model.predict([10])
# Out:
# array([[30.997343]], dtype=float32)
